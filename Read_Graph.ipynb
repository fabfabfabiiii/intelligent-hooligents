# %%
import networkx as nx

# %%
graph = nx.read_graphml("./resources/Verkehrsnetz.graphml")
print(graph.nodes()["11"])
# Out:
# {'label': 'Test123'}

# %%
nx.draw_networkx(graph, font_size=12, node_color="blue", with_labels=True)
